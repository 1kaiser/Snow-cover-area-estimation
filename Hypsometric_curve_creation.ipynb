# %% [markdown]
# <a href="https://colab.research.google.com/github/1kaiser/Snow-cover-area-estimation/blob/main/Hypsometric_curve_creation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**[Hypsometric spreadsheet](https://docs.google.com/spreadsheets/d/1yOFEmha__J8yDo0gUBbnZ4m6xM_I_wQ0K6xSldy0Qag/edit?usp=sharing)** ⬅️go to this sheet then select the YEAR and copy&paste the data here ⬇️🔽⏬
#
# ![image](https://private-user-images.githubusercontent.com/26379748/240975682-90864bf2-de43-4d76-a7ea-315a9886a66c.png?jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJrZXkiOiJrZXkxIiwiZXhwIjoxNjg1MDMyMDQyLCJuYmYiOjE2ODUwMzE3NDIsInBhdGgiOiIvMjYzNzk3NDgvMjQwOTc1NjgyLTkwODY0YmYyLWRlNDMtNGQ3Ni1hN2VhLTMxNWE5ODg2YTY2Yy5wbmc_.jp_tkxmtAXVAahpqDdzUOEbEzInKXOAJkseDgvbWf_A)

# %%
A = [

[0.07,1,1,1,1],
[0.14,1,1,1,1],
[0.21,0.99383120308005,0.996800560484902,0.998634802056453,0.997331069166385],
[0.29,0.911047738182711,0.950279958857575,0.980560436870878,0.963852365596564],
[0.36,0.430336284869624,0.659742225464315,0.850996941518942,0.723888127941647],
[0.43,0.0957641008359422,0.367065212334639,0.649381465942444,0.368638191020471],
[0.50,0.0559392138072259,0.186552177069844,0.441014882147055,0.0963455158621069],
[0.57,0.0527896858831757,0.0849047671186346,0.273578792862024,0.011480048440965],
[0.64,0.0499730715199438,0.0322568251861063,0.140746033672644,0.00320061937748672],
[0.71,0.0472446536182909,0.0133014830488213,0.0448279222131287,0.00320061937748672],
[0.79,0.0452017762186794,0.00802505499765632,0.00676606037909624,0.00320061937748672],
[0.86,0.0435926302940851,0.00724121120488892,0.00156261492616753,0.00320061937748672],
[0.93,0.0428994694807764,0.00711391996252639,0.00138738302271976,0.00320061937748672],
[1.00,0.0302093322182466,0.00698662872016387,0.00138738302271976,0.00320061937748672],

]

# %%
# @title ✅✅ **running checks** ✅✅ { vertical-output: true }
x =[]
EW =[]
SS =[]
MS =[]
PW =[]
for i in range(len(A)):
  print(A[i])
  x.append(A[i][0])
  EW.append(A[i][1])
  SS.append(A[i][2])
  MS.append(A[i][3])
  PW.append(A[i][4])
##############################################################################################################################

y1 =[[0,1],
[0.024,0.96],
[0.038,0.917],
[0.054,0.864],
[0.076,0.831],
[0.111,0.785],
[0.149,0.762],
[0.196,0.735],
[0.237,0.712],
[0.278,0.695],
[0.313,0.682],
[0.348,0.675],
[0.389,0.662],
[0.421,0.659],
[0.456,0.646],
[0.497,0.636],
[0.535,0.623],
[0.566,0.619],
[0.595,0.613],
[0.63,0.603],
[0.652,0.599],
[0.687,0.586],
[0.709,0.579],
[0.741,0.57],
[0.769,0.563],
[0.797,0.55],
[0.823,0.54],
[0.848,0.533],
[0.873,0.517],
[0.896,0.503],
[0.921,0.493],
[0.946,0.466],
[0.962,0.454],
[0.968,0.242],
[0.978,0.107],
[0.986,0.089],
[1,0],]

m1 =[[0,1],
[0.024,0.854],
[0.035,0.791],
[0.047,0.725],
[0.06,0.679],
[0.073,0.642],
[0.085,0.619],
[0.101,0.583],
[0.117,0.55],
[0.149,0.51],
[0.174,0.487],
[0.199,0.467],
[0.228,0.44],
[0.263,0.424],
[0.342,0.391],
[0.383,0.377],
[0.424,0.361],
[0.453,0.351],
[0.491,0.334],
[0.516,0.328],
[0.544,0.321],
[0.611,0.298],
[0.642,0.291],
[0.674,0.278],
[0.706,0.268],
[0.741,0.258],
[0.766,0.252],
[0.797,0.242],
[0.823,0.232],
[0.851,0.222],
[0.883,0.199],
[0.911,0.192],
[0.937,0.172],
[0.959,0.156],
[0.972,0.142],
[0.983,0.123],
[1,0],]

o1 =[[0,1],
[0.024,0.795],
[0.035,0.719],
[0.041,0.623],
[0.057,0.483],
[0.079,0.401],
[0.095,0.361],
[0.111,0.328],
[0.13,0.301],
[0.149,0.275],
[0.168,0.252],
[0.225,0.209],
[0.241,0.199],
[0.259,0.192],
[0.278,0.182],
[0.297,0.175],
[0.316,0.169],
[0.361,0.156],
[0.386,0.146],
[0.443,0.132],
[0.462,0.129],
[0.478,0.123],
[0.513,0.113],
[0.535,0.106],
[0.56,0.103],
[0.62,0.093],
[0.674,0.086],
[0.696,0.079],
[0.734,0.076],
[0.756,0.073],
[0.775,0.07],
[0.861,0.053],
[0.88,0.053],
[0.905,0.05],
[0.962,0.04],
[0.979,0.026],
[1,0],]
##############################################################################################################################
youthx = []
youthy = []
maturex = []
maturey = []
oldx =[]
oldy =[]

for i in range(len(y1)):
  youthx.append(y1[i][0])
  youthy.append(y1[i][1])

for i in range(len(m1)):
  maturex.append(m1[i][0])
  maturey.append(m1[i][1])

for i in range(len(o1)):
  oldx.append(o1[i][0])
  oldy.append(o1[i][1])
# Out:
# [0.07, 1, 1, 1, 1]
# [0.14, 1, 1, 1, 1]
# [0.21, 0.99383120308005, 0.996800560484902, 0.998634802056453, 0.997331069166385]
# [0.29, 0.911047738182711, 0.950279958857575, 0.980560436870878, 0.963852365596564]
# [0.36, 0.430336284869624, 0.659742225464315, 0.850996941518942, 0.723888127941647]
# [0.43, 0.0957641008359422, 0.367065212334639, 0.649381465942444, 0.368638191020471]
# [0.5, 0.0559392138072259, 0.186552177069844, 0.441014882147055, 0.0963455158621069]
# [0.57, 0.0527896858831757, 0.0849047671186346, 0.273578792862024, 0.011480048440965]
# [0.64, 0.0499730715199438, 0.0322568251861063, 0.140746033672644, 0.00320061937748672]
# [0.71, 0.0472446536182909, 0.0133014830488213, 0.0448279222131287, 0.00320061937748672]
# [0.79, 0.0452017762186794, 0.00802505499765632, 0.00676606037909624, 0.00320061937748672]
# [0.86, 0.0435926302940851, 0.00724121120488892, 0.00156261492616753, 0.00320061937748672]
# ...

# %%
#@title 📈 **plot the curves**
year = "2019 JULY - 2020 JUNE" #@param {type:"string"}
image_quality = 300 #@param {type:"slider", min:100, max:900, step:100}
font_size = 12
marker_type = "line" #@param ["marker", "line"]

import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(5, 5), dpi=image_quality)

if marker_type == "marker":
    marker = 'o'
    markersize = 4
    linestyle = 'None'
else:
    marker = None
    markersize = None
    linestyle = '-'

ax.plot(youthx, youthy, c='green', label="Young", marker=marker, markersize=markersize, linestyle=linestyle)
ax.plot(maturex, maturey, c='blue', label="Mature", marker=marker, markersize=markersize, linestyle=linestyle)
ax.plot(oldx, oldy, c='black', label="Old", marker=marker, markersize=markersize, linestyle=linestyle)

ax.plot(EW, x, marker=marker, markersize=markersize, c='red', label="EW(JAN-FEB)", linestyle=linestyle)
ax.plot(SS, x, marker=marker, markersize=markersize, c='pink', label="SS(FEB-JUN)", linestyle=linestyle)
ax.plot(MS, x, marker=marker, markersize=markersize, c='cyan', label="MS(JUL-OCT)", linestyle=linestyle)
ax.plot(PW, x, marker=marker, markersize=markersize, c='magenta', label="PW(NOV-DEC)", linestyle=linestyle)

ax.legend(loc='upper right', prop={'size': 8})

ax.set_xlabel('Relative Area', fontsize=font_size)
ax.set_ylabel('Relative Height', fontsize=font_size)
ax.set_title('Snow Cover Hypsometric curve ' + str(year), fontsize=font_size)

ax.tick_params(axis='both', which='major', labelsize=font_size)

ax.grid(True)
fig.savefig(str(year) + ".png")
plt.show()
